# %% [markdown]
# https://medium.com/featurepreneur/image-data-augmentation-using-keras-imagedatagenerator-1cee60255ea8

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # **All classes: Brightness**

# %%
import cv2 as cv
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# ImageDataGenerator class
datagen = ImageDataGenerator(brightness_range=[0.2,0.8])

#loop over the data in batches and this automatically saves the images
i = 0
for batch in datagen.flow_from_directory('/content/drive/MyDrive/Colab Notebooks/Master Thesis/Ultrasound_fetus/CRL', batch_size=10,target_size=(720,960),
                          save_to_dir='/content/drive/MyDrive/Colab Notebooks/Master Thesis/Ultrasound_fetus/Augmented Images/With mask/Brightness', save_format='jpg'):
    i += 1
    if i > 9:
        break
# Out:
# Found 125 images belonging to 3 classes.

# %%
import cv2
import os

def load_images_from_folder(folder):
    images = []
    for filename in os.listdir(folder):
        img = cv2.imread(os.path.join(folder,filename))
        if img is not None:
            images.append(img)
    return images

# %%
images_br = load_images_from_folder('/content/drive/MyDrive/Colab Notebooks/Master Thesis/Ultrasound_fetus/Augmented Images/With mask/Random Rotation')
len(images_br)
# Out:
# 156

# %% [markdown]
# # **All classes: Horizontal Flip**

# %%
import cv2 as cv
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# ImageDataGenerator class
datagen = ImageDataGenerator(horizontal_flip=True)

#loop over the data in batches and this automatically saves the images
i = 0
for batch in datagen.flow_from_directory('/content/drive/MyDrive/Colab Notebooks/Master Thesis/Ultrasound_fetus/CRL', batch_size=9,target_size=(720,960),
                          save_to_dir='/content/drive/MyDrive/Colab Notebooks/Master Thesis/Ultrasound_fetus/Augmented Images/With mask/Horizontal Flip', save_format='jpg'):
    i += 1
    if i > 9:
        break
# Out:
# Found 125 images belonging to 3 classes.

# %% [markdown]
# # **All classes: Random Rotation**

# %%
# ImageDataGenerator class
datagen = ImageDataGenerator(rotation_range=15)

#loop over the data in batches and this automatically saves the images
i = 0
for batch in datagen.flow_from_directory('/content/drive/MyDrive/Colab Notebooks/Master Thesis/Ultrasound_fetus/CRL', batch_size=6,target_size=(720,960),
                          save_to_dir='/content/drive/MyDrive/Colab Notebooks/Master Thesis/Ultrasound_fetus/Augmented Images/With mask/Random Rotation', save_format='jpg'):
    i += 1
    if i > 12:
        break
# Out:
# Found 125 images belonging to 3 classes.

# %% [markdown]
# # **CLASS 0: Brightness**

# %%
import cv2 as cv
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# ImageDataGenerator class
datagen = ImageDataGenerator(brightness_range=[0.2,0.7])

#loop over the data in batches and this automatically saves the images
i = 0
for batch in datagen.flow_from_directory('/content/drive/MyDrive/Colab Notebooks/Master Thesis/Ultrasound_fetus/CRL/CRL_0', batch_size=9,target_size=(720,960),
                          save_to_dir='/content/drive/MyDrive/Colab Notebooks/Master Thesis/Ultrasound_fetus/Augmented Images/CRL/CRL_0_Brightness', save_format='jpg'):
    i += 1
    if i > 9:
        break

# %% [markdown]
# # **CLASS 0: Horizontal Flip**

# %%
import cv2 as cv
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# ImageDataGenerator class
datagen = ImageDataGenerator(horizontal_flip=True)

#loop over the data in batches and this automatically saves the images
i = 0
for batch in datagen.flow_from_directory('/content/drive/MyDrive/Colab Notebooks/Master Thesis/Ultrasound_fetus/CRL/CRL_0', batch_size=9,target_size=(720,960),
                          save_to_dir='/content/drive/MyDrive/Colab Notebooks/Master Thesis/Ultrasound_fetus/Augmented Images/CRL/CRL_0_Horizontal Flip', save_format='jpg'):
    i += 1
    if i > 9:
        break
# Out:
# Found 36 images belonging to 2 classes.

# %%
from PIL import Image
import glob
images_hf = []
for filename in glob.glob('/content/drive/MyDrive/Colab Notebooks/Master Thesis/Ultrasound_fetus/Augmented Images/CrossAugmentation_HorizontalFlip/*.jpg'):
    im=Image.open(filename)
    images_hf.append(im)
    
print(len(images_hf))
# Out:
# 406

# %% [markdown]
# # **CLASS 0: Random Rotation**

# %%
# ImageDataGenerator class
datagen = ImageDataGenerator(rotation_range=15)

#loop over the data in batches and this automatically saves the images
i = 0
for batch in datagen.flow_from_directory('/content/drive/MyDrive/Colab Notebooks/Master Thesis/Ultrasound_fetus/CRL/CRL_0', batch_size=6,target_size=(720,960),
                          save_to_dir='/content/drive/MyDrive/Colab Notebooks/Master Thesis/Ultrasound_fetus/Augmented Images/CRL/CRL_0_Rotation', save_format='jpg'):
    i += 1
    if i > 12:
        break
# Out:
# Found 36 images belonging to 2 classes.

# %%
images_rr = load_images_from_folder('/content/drive/MyDrive/Colab Notebooks/Master Thesis/Ultrasound_fetus/Augmented Images/Random Rotation2')
len(images_rr)
# Out:
# 132

# %% [markdown]
# # **CLASS 1: Brightness**

# %%
import cv2 as cv
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# ImageDataGenerator class
datagen = ImageDataGenerator(brightness_range=[0.2,0.7])

#loop over the data in batches and this automatically saves the images
i = 0
for batch in datagen.flow_from_directory('/content/drive/MyDrive/Colab Notebooks/Master Thesis/Ultrasound_fetus/CRL/CRL_1', batch_size=9,target_size=(720,960),
                          save_to_dir='/content/drive/MyDrive/Colab Notebooks/Master Thesis/Ultrasound_fetus/Augmented Images/CRL/CRL_1_Brightness', save_format='jpg'):
    i += 1
    if i > 9:
        break
# Out:
# Found 46 images belonging to 2 classes.

# %% [markdown]
# # **CLASS 1: Horizontal Flip**

# %%
import cv2 as cv
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# ImageDataGenerator class
datagen = ImageDataGenerator(horizontal_flip=True)

#loop over the data in batches and this automatically saves the images
i = 0
for batch in datagen.flow_from_directory('/content/drive/MyDrive/Colab Notebooks/Master Thesis/Ultrasound_fetus/CRL/CRL_1', batch_size=9,target_size=(720,960),
                          save_to_dir='/content/drive/MyDrive/Colab Notebooks/Master Thesis/Ultrasound_fetus/Augmented Images/CRL/CRL_1_Horizontal Flip', save_format='jpg'):
    i += 1
    if i > 9:
        break
# Out:
# Found 46 images belonging to 2 classes.

# %% [markdown]
# # **CLASS 1: Random Rotation**

# %%
# ImageDataGenerator class
datagen = ImageDataGenerator(rotation_range=15)

#loop over the data in batches and this automatically saves the images
i = 0
for batch in datagen.flow_from_directory('/content/drive/MyDrive/Colab Notebooks/Master Thesis/Ultrasound_fetus/CRL/CRL_1', batch_size=6,target_size=(720,960),
                          save_to_dir='/content/drive/MyDrive/Colab Notebooks/Master Thesis/Ultrasound_fetus/Augmented Images/CRL/CRL_1_Rotation', save_format='jpg'):
    i += 1
    if i > 12:
        break
# Out:
# Found 46 images belonging to 2 classes.

# %% [markdown]
# # **CLASS 2: Brightness**

# %%
import cv2 as cv
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# ImageDataGenerator class
datagen = ImageDataGenerator(brightness_range=[0.2,0.7])

#loop over the data in batches and this automatically saves the images
i = 0
for batch in datagen.flow_from_directory('/content/drive/MyDrive/Colab Notebooks/Master Thesis/Ultrasound_fetus/CRL/CRL_2', batch_size=9,target_size=(720,960),
                          save_to_dir='/content/drive/MyDrive/Colab Notebooks/Master Thesis/Ultrasound_fetus/Augmented Images/CRL/CRL_2_Brightness', save_format='jpg'):
    i += 1
    if i > 9:
        break
# Out:
# Found 43 images belonging to 2 classes.

# %% [markdown]
# # **CLASS 2: Horizontal Flip**

# %%
import cv2 as cv
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# ImageDataGenerator class
datagen = ImageDataGenerator(horizontal_flip=True)

#loop over the data in batches and this automatically saves the images
i = 0
for batch in datagen.flow_from_directory('/content/drive/MyDrive/Colab Notebooks/Master Thesis/Ultrasound_fetus/CRL/CRL_2', batch_size=9,target_size=(720,960),
                          save_to_dir='/content/drive/MyDrive/Colab Notebooks/Master Thesis/Ultrasound_fetus/Augmented Images/CRL/CRL_2_Horizontal Flip', save_format='jpg'):
    i += 1
    if i > 9:
        break
# Out:
# Found 43 images belonging to 2 classes.

# %% [markdown]
# # **CLASS 2: Random Rotation**

# %%
# ImageDataGenerator class
datagen = ImageDataGenerator(rotation_range=15)

#loop over the data in batches and this automatically saves the images
i = 0
for batch in datagen.flow_from_directory('/content/drive/MyDrive/Colab Notebooks/Master Thesis/Ultrasound_fetus/CRL/CRL_2', batch_size=6,target_size=(720,960),
                          save_to_dir='/content/drive/MyDrive/Colab Notebooks/Master Thesis/Ultrasound_fetus/Augmented Images/CRL/CRL_2_Rotation', save_format='jpg'):
    i += 1
    if i > 12:
        break
# Out:
# Found 43 images belonging to 2 classes.
